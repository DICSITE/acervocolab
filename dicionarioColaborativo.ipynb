# %% [markdown]
# <a href="https://colab.research.google.com/github/DICSITE/acervocolab/blob/main/dicionarioColaborativo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# O primeiro valor é a palavra em português e o segundo indígena

dic_indigena = {'amar': 'hayhu (Paresí) ou uzamutar (Guajajara) ',
                "alma" : 'anhang (Tupi) ' ,
                "água": 'y ou ty (Tupi) ou â (Xavante) outuna (Apalaí)  ou Água funda = ârehâ (Xavante) ou Água parada = u (Xavante) ou Água adoçada = âze (Xavante)',
                "aracanguira" : 'abacataia ou Abacatuia (Tupi)',
                "amigo" : 'amigo de roupa preta = Abaruna (Tupi) ou amigo dos papagaios = Ararê (Tupi)',
                "ave" : "ave branca = Acará (Tupi)",
                "amarelo": 'Ajubá',
                "árvore": "aramari apo (Apalaí) ou atya (paresi-haliti) ou árvore de madeira dura = Ajuru (Tupi)",
                "anão":'Anãmiri (Tupi)',
                "acamim": 'Iacamim (Tupi)',
                "açaí": 'Uaçai ou yasaí (Tupi)',
                "arara": 'A rara (Tupi)',
                "abelha":'Arapuá (Tupi)',
                "anta":'Tapir(Tupi)',
                "abondonado":'Ītu(Xavante)',
                "acertar":'Japete(Tupi)',
                "aconselhar":'Wada uri(Xavante)',
                "aguaí-da-mata" : 'agwai ka agwy (kaiowá)',
                "aguape" : 'agwape (kaiowá)',
                "agradecimento" : 'agwyjeme ē (kaiowá)',
                "aniversário" : 'ajogwe a (kaiowá)',
                "apaixonado" : 'akã raku (kaiowá)',
                "abundância" : "orévy(kaiowá)",
                "agradecimento" : "agwyjeme'e (kaiowá)",
                'aniversário' : 'ajogwe a (kaiowá)',
                'apaixonado' : 'akã raku (kaiowá)',



                "beber":" `u ( tupinambá)",
                "boca":"a,chau-a (tikúna)",
                "bravo":"acê (kaipó)",
                "braço (o)":"agnipcaton (pataxó)",
                "brilhar":"niongnitochingá (pataxó)",
                "barba":"aivánindivá (apiacá)",
                "bonito":"porang (tupi)",
                "bom":"katu (tupi)",
                "brilhante":"beraba (eburiini)",
                "baiacu":"mbaéacu (tupi)",
                "bauru":"upaurú (tupi)",
                "biboca":"ymby mbóka (Tupi)",
                "banana" : 'pakova (Kaiowá)' ,
                "banana nanica" : 'pakova karape (Kaiowá)' ,
                "banana maçã" : 'pakova masã (Kaiowá)' ,
                "banana prata" : 'pakova pytã (Kaiowá)' ,
                "bacuri" : 'pakuri (Kaiowá)' ,
                "borboleta" : 'panambi (Kaiowá)' ,
                'broto' : 'agwape i (kaiowá)',



                'cabeça':'nôçueri (Paresí) ou akag (tupi-guarani)',
                "casa": "oka (tupi)",
                'chuva':'amana ou Amanda (tupi antigo) ou munhâm (tupi-guarani)',
                'carro':'piaçava (tupi)',
                'cuida':'cuia ou dhui (tupi)',
                'curso':'tremembé ou Oiapoque ou jurubatuba(tupi)',
                'caipora':'caapuã(tupi)',
                'cabloco':'kariboka(tupi)',
                'cheio':'abiró ou bá(tupi)',
                'cocar':'acangatara(tupi)',
                'caju':'akaîu(tupi)',
                'centopeia':'ambûá(tupi)',
                'colo':'anhuri(tupi)',
                'coruja':'aondê(tupi)',
                'caminho':'apé(tupi)',
                'crespo':'apichai(tupi)',
                'chama':'ataendy(tupi)',
                'caranguejo':'auçá(tupi)',
                'catequista':'avaré(tupi)',
                'canta':'cê(tupi)',
                'carioca':'kari(Tupi-Guarani)',
                'cacau':'cacauatl (Náhuatle)',
                'caipira':'caaipura (Tupi-Guarani)',
                'caatinga':'caá-t-enga (Tupi-Guarani)',
                'caiçara':'caá-içara (Tupi-Guarani)',
                'capim':'caá (Tupi-Guarani) ou caapii (tupinambá)',
                'capoeira':'co-poera (Tupi-Guarani)',
                'capivara':'kapiiguara (Tupi-Guarani)',
                'catuaba':'caá (Tupi-Guarani)',
                'cipó':'ici-fila (Tupi-Guarani)',
                'copacabana':'kupa kawana (quechua)',
                'cutia':'a-cuti (Tupi-Guarani)',
                 'casa':'oka (tupi-guarani)',
                'cutucar':'kútuk (tupinambá)',
                'comida':'mangút (tupi-guarani)',
                'cacto':'jumbeba (tupi-guarani)',
                'curto':'aquitã (tupi-guarani)',
                'catapora':'tatapora (tupi)',
                'catupiry':'catupiri (tupi)',
                'cacau':'cacautl (nahuatl)',
                "conclusão" : "agwyje (kaiowá)",
                'chapéu' : 'akā aho iha (kaiowá) ',



                'dente':'naikurí (Paresí)',
                "dia" : 'dia chuvoso = Amanara(Tupi) ou Dia de chuva = Amandy(Tupi)',
                'distante':'Anomatí(Tupi)',
                'dor':'Acemira(Tupi)',
                'duende':'Anãmiri(Tupi)',
                'deusa' : 'deusa das águas = Yara(Tupi) ou Deusa da mandioca = Maní(Tupi)',
                'deus' : 'deus do amor = Rudá(Tupi)',
                'da mesma região':'Javaé(Tupi)',
                "descontar" : "ahéi (kaiowá)",
                "descendente" : 'paĩ (Kaiowá)' ,
                'daqui' : 'ágwi (kaiowá)',
                'depilar' : '(o-h)agwe o (kaiowá)',




                "ele": 'italá (Paresí)',
                "esquecimento": "Eçaraia (tupi)",
                "enfraquecer" : "hato (Xavante)",
                "enganar" : 'hapetse (Xavante)',
                "elástico": ' ännhatä (Ye kwana)',
                "emendar":'ichotontädö (Ye Kwana)',
                "enchente":'chuumadö (Ye Kwana)',
                "escada":"kadeeda (Ye Kwana)",
                "escorpião":"mönäätä (Ye Kwana)",
                "empurrado":" anhana (Tupi)",
                "espinho":"Ju (Tupi)",
                "estrela":"îasytatá(Tupi) ou wasi(Xavante)",
                'encolhido' : 'akhra a (kaiowá)',



                'falar':'Niaurí (Paresí) ou Nhe (Tupi) ou fala inteligente = Nanbiquara (Tupi) ou falação = Nhenhenhém (Tupi)',
                'fogo':'Tatá (Nheengatu) ou turi (Tupi)',
                'fogueira':'Turi (Tupi) ou Atagûasu (Tupi)',
                'felicidade':'Angatu (Tupi)',
                'face':'nuca-cuiá (Baniwa)',
                'floresta':'ka´a (Tupi) ou segredo na floresta = thiago (herói)',
                "forte" : "Antã ou Atã (Tupi)" ,
                "formosa" : "Aisó (Tupi)" ,
                "filha": " Aiyra (Tupi) ",
                "fruta": "com grande quantidade de vitamina = Camu-camu (Tupi)",
                "fruta":" com espinho = Ajuhá (Tupi) ou ma'ywa (Guajajara) ou  fruta verde = zusery (Apalaí) ou rob'rã (Xavanti)",
                "flor" : "Fulô (Tupi)",
                'farinha':'ma-tçoca (Baniwa)',
                'feio':'dôpo (Baniwa)',
                'frio':'a-pêrri (Baniwa)',
                'febre':'tacûa (Baniwa)',
                'furtar':'Naquin (Apinayé)',
                " finado":"Amyri (Tupi)",
                "faca":"cápa (Baniwa)",
                "formiga":"saúva (Tupi) ou hamé (Baniwa)",
                "fugir":"Jabá (Tupi)" ,
                'filho' : 'Membira (Tupi) ou Membyra (Tupi Antigo)' ,
                'folha' : 'Cáa (Tupi) ou folha jurubeba = ru (Tupi)',
                "fumaça":"Amerê (Tupi)" ,
                'flecha' : 'Pyrou (Apalaí) ou Crúa (Apinayé) ou Na (Kaingang)' ,
                'filho' : 'kósin (Kaingang)' ,
                'família': 'anama (Tupi)' ,
                'fantasma' : 'angoera (Tupi)' ,
                "feixe" : "apytama (Tupi)" ,
                "formiguinha" : 'aimirim (Tupi)' ,
                "formosa" : 'aisó (Tupi)' ,


                "gelo":"Yro'y (Tupi-guarani)",
                "golfinho":"Araranguá (tupi- guarani)",
                "garça":'Acará (tupi-guarani)',
                "galinha" :'takuirá (Paresí)',
                "guerreiro" : "Guariní (tupi-guarani)" ,
                "girassol" : "dasi'wapé (xavante)" ,
                "gente" : "Abá (tupi-guarani)" ,
                "garota" : "cunhantã (tupi-guarani)" ,
                "garoto" : "Curumim (tupi-guarani)",
                "grande":"Açu (Tupi)",
                "grosso": "Anama (Tupi)",
                "guaia (Caranguejo)": "Aauçá (Tupi)",
                "guariba":"Wa'riwa (Tupi)",
                "gato":"Yawara (Tupi)",
                "girar":"Baka (Tupinambá)",
                "gigante":"Abaçai (Tupinambá)",
                "guerra":"Marana (Tupinambá)",
                "gordura":"Kaba (Tupinambá)",
                "grama":"Ka'a (Tupinambá)",
                "gaivota":"Ati (Tupi) ou Gaivota grande = Atiati (Tupi)",
                "gênio":"Yacamim (Tupi)",
                "guerrear" : "tamambuê ahat ( Mawé)" ,
                "gratidão" : "HA'EVEte (tupi-guarani)" ,
                "grilo" : "kôxí (kaiapó)" ,
                "guardar" : "tiçâa (kaiapó)" ,
                "gritar" : "Asema (tupi-guarani)" ,
                 "gordo": 'abirú (Tupi) ' ,
                "girassol" : 'paĩ poty (Kaiowá)' ,
                'garoa' : 'amandayvi (kaiowá)',
                'garganta' : 'ahy o (kaiowá)',
                'genro' : 'iñj (kaiowá)',





                'homem':'ená (Paresí) ou Atuá ou Abá (Tupi) ou kariay (kaiwá) ou Homem verdadeiro = Abaeté (Tupi) ou homem que voa = Abaquar (Tupi) ou homem do mato = cambé (tupi) ou homem branco = Cari (Tupi)',
                'hoje': 'cuitirí (guajajara)',
                'honrado':'etê (tupi)',
                'humano': 'maajaama (yekwana)',


                'ir':'iantá (Paresí)',
                'imprestável':'Iua',
                'iba': 'Iwa (tupi-guarani)',
                'indivíduo':'Indivíduo de peito negro = jacaúna (tupi-guarani) ou indivíduo atarracado = Caburé (tupi)',
                'índio':'Abá ou Avá ou Auá (tupi-guarani)',
                'igreja':'tupao (tupi-guarani)',
                'idioma':'damreme (Xavante)',
                'inteiramente':'ejete (tupi)',
                'intervalo':'ai-ai (tupi)',
                'inquieto':'ara-á (tupi)',
                'ibirapuera' : 'ibirá-puera (Tupi-Guarani)' ,
                "intervalo" : 'pa ũ (Kaiowá)' ,
                "inferno" : 'pa i rei (Kaiowá)' ,



                'jandaia':'kuíri (Paresí)',
                'jerimum':'Yurumún (Tupi-guarani)',
                'jiboia':'Jy (Tupi-guarani)',
                'jabuti':'Karumbe (Tupi-Guarani)',
                'jaca':'Kavaju (Tupi-Guarani)',
                'joelho':'Penarã (Tupi-Guarani)',
                'jacaré':'jarça',
                'junto':'Âguĩ (Tupi-Guarani)',
                'janeiro':'Jasyteĩ (Tupi-Guarani)',
                'jesus':'Hesu',
                'jovem':'Cururim (Tupi-Guarani)',
                'janta':'Cená ou Karu (Tupi-Guarani)',
                'jangada':'Igapeba (Tupi-Guarani)',
                'jogar':'Temamián (Tupi-Guarani)',
                'judiar':'Tinaprê (Tupi-Guarani)',
                'jaçanã' : 'agwapeaso' (kaiowá)',


                'katipé (árvore)':'uhiça (Paresí)',


                'luz':'mentuktire (Tupi)',
                "líder espiritual" : 'pa i hechakáry (Kaiowá)' ,
                'lobo guará' : 'agwara (kaiowá)',


                'mãe':'mamá ou amá (Paresí) ou sy (Tupi antigo)',
                'mar':'paranã (Tupi antigo)',
                'moça':'Zuimáhalutí (Paresí)',
                'morro':'Zaúna (Paresí)',
                'mosquito':'Zaúna (Paresí)',
                'mingau de mandioca':'Katazeurê (Paresí)',
                'mingau de milho':'Kamulazá (Paresí)',
                'milho':'Abati (Tupi-Guarani)',
                'mensageiro':'Amanajé (Tupi-Guarani)',
                'morcego':'Andirá',
                'marimbondo':'Caba (Tupi-Guarani)',
                'mel':'Ira (Tupi-Guarani)',
                'maracanã':'paracau-aná (Tupi-Guarani)',
                'mingau':'mi-caú (Tupi-Guarani)',
                'mocotó':'mo-coto (Tupi-Guarani)',
                'mutirão':'pitibõ ou popitibõ ou picorõ (Tupi-Guarani)',
                'mutum':'plumagem (Tupi-Guarani)',
                'monte de conchas':'Tambakï (Tupi)',
                'moqueca':'Pokeka (Tupi)',
                'macaco':'Sagüi (Tupi-Guarani)',
                'mestiço':'Mamai-ruuca (Tupi-Guarani)',
                'mãe dágua':'Yara (Tupi)',
                "manca" : 'parĩ (Kaiowá)',
                "mar" : 'para (Kaiowá)' ,
                'muito obrigado' : 'agwjevete (kaiowá)',



                'nariz':'nhãpynha (Kawahiva)',
                'não':'maiçá (Paresí) ou Ñiá (Tupi-guarani)',
                'nós':'íandé(tupi antigo)',
                'nevoeiro':'ibitinga(Tupi-guarani)',
                'nuvem':'uaaté (Tupi-guarani)',
                'ninho':'Araraquara (Tupi) ou Ayty (Tupi)',
                'nascer':'nascer do dia = Aracê (Tupi)',
                'noite':'Pituna (Tupi) ou yputuna (Kawahiva) ',
                'nômade':'goitacá (Kawahiva) ',
                'nuca' :'jirypya (Kawahiva) ',
                "nuvem" : 'paráry (Kaiowá)' ,
                "noivo" : 'abaíba (Tupi) ' ,


                'olho de boi':'onoê (Paresí)',
                'onça-hu' :'(xavante)',
                'oka':'casa de indio v.ocara, manioca ( Tupi)',
                'onça':'jini (Tupi) Auiató (Mawé)',
                'ore':'caçar animais pequenos (Tupi)',
                'oi':'anauê (Tupi)',
                'olho':'Oheha (Mawé)',
                'orelha':'Uihapê (Mawé)',
                 "ontem" : "Nhaatpó (Mawé)",


                "pedra": 'ita (Tupi)',
                'pai' : 'damama (Xavante) ou tuba (Tupi antigo)' ,
                'papagaio' : 'waihârâ (Xavante) ou azuru (Guajajara)' ,
                'peixe' : 'pirá (Tupi antigo) ou arumaxi (apalaí)' ,
                'pequeno' : 'mirim (Tupi antigo)',
                "papagaio" : 'parakáu (Kaiowá)' ,
                "pacu" : 'paku (Kaiowá)' ,
                'pobrezinho(a)' : 'aichejáragai (kaiowá)',



                'quina':'ahonlê (Paresí)',

                'rede':'maká (Paresí)',
                'raposa': 'agwara cha ī (kaiowá)',


                "sol" : "kûarasy (Tupi)",
                "sabiá": 's-apia ( tupi)' ,
                "saci-perere" : 'çá-aci (tupi)',
                "sonhar": 'Aquahú (Guajajara)',
                "sim": 'Eré (Guajajara)',
                'sujo': 'Kiá (nheengatu)',
                "sítio" : "Tendaua (nheengatu)",
                "sentar" :'Duhicé (Tucana)',
                "soprar" : 'Pukticé (Tucana)',
                'surdo' : 'Çampanón (Kaiapo)',
                'sumir':'Itó (Kaiapo)',
                'saber':'Epu`tî (Makuxi)',
                'sair': 'Anrîmaka (Makuxi)',
                'sincero': 'Etê (Tupi)',
                'seio': 'Camb (Tupi)',
                "sacerdote" : ' pa i (Kaiowá)',
                "sol" : 'Pa i Kwara (Kaiowá)' ,


                'terra':'uaikôen (Paresí)',
                'tontura' : 'akãnga u (kaiowá)',


                'urubu':'olohôn (Paresí)',


                'veneno':'zamarí (Paresí)',


                "quando": 'tikat (Karitiána)',
                "quatro": 'otadnamynt (Tupi)',
                "queimar": 'pipop (Tupi)',
                "quem": "morã (Tupi) ou mobo (Karajá)",







                "xamã" :'Pa i Jirutipu (Kaiowá)',
















}
while True:

  palavra = input("Digite Palavra em portugues: ")
  if palavra in dic_indigena:
    valor = dic_indigena[palavra]
    print("A correspondencia à palavra", palavra, "é", valor)
  else:
    print("Desculpe, ainda não catalogamos esta palavra.")
#Buscando valor com base na chave
#if palavra == dic_indigena.get(input("Digite a palavra em portugues: ")):
#if palavra == dic_indígena:
#  print(palavra)
#else:  # Está linha de código para informar que não temos a palavra
#  print('Desculpe, ainda não catalogamos esta palavra')
# Out:
#   File "<ipython-input-2-8ae6a74083d1>", line 237
#     'jaçanã' : 'agwapeaso' (kaiowá)',
#                                    ^
# SyntaxError: unterminated string literal (detected at line 237)

# %%
# O primeiro valor é a palavra em português e o segundo indígena

dic_indigena = {'amar': 'hayhu (Paresí) ou uzamutar (Guajajara) ',
                "alma" : 'anhang (Tupi) ' ,
                "água": 'y ou ty (Tupi) ou â (Xavante) outuna (Apalaí)  ou Água funda = ârehâ (Xavante) ou Água parada = u (Xavante) ou Água adoçada = âze (Xavante)',
                "aracanguira" : 'abacataia ou Abacatuia (Tupi)',
                "amigo" : "amigo de roupa preta = Abaruna (Tupi) ou amigo dos papagaios = Ararê (Tupi)",
                "ave" : "ave branca = Acará (Tupi)",
                "amarelo": 'Ajubá',
                "Árvore": "aramari apo (Apalaí) ou atya (paresi-haliti) ou árvore de madeira dura = Ajuru (Tupi)",
                "anão":'Anãmiri (Tupi)',
                "acamim": 'Iacamim (Tupi)',
                "açaí": 'Uaçai ou yasaí (Tupi)',
                "arara": 'A rara (Tupi)',
                "abelha":'Arapuá (Tupi)',
                "Anta":'Tapir(Tupi)',
                "Abondonado":'Ītu(Xavante)',
                "Acertar":'Japete(Tupi)',
                "Aconselhar":'Wada uri(Xavante)',
                "amigo":'amigo dos papagaios(Tupi)',
                "abundância" : "orévy(kaiowá)",
                "agradecimento" : "agwyjeme'e (kaiowá)",


                "beber":" `u ( tupinambá)",
                "boca":"a,chau-a (tikúna)",
                "bravo":"acê (kaipó)",
                "braço (o)":"agnipcaton (pataxó)",
                "brilhar":"niongnitochingá (pataxó)",
                "barba":"aivánindivá (apiacá)",
                "bonito":"porang (tupi)",
                "bom":"katu (tupi)",
                "brilhante":"beraba (eburiini)",
                "Baiacu":"mbaéacu (tupi)",
                "Bauru":"upaurú (tupi)",
                "Biboca":"ymby mbóka (Tupi)",
                "banana" : 'pakova (Kaiowá)' ,
                "banana nanica" : 'pakova karape (Kaiowá)' ,
                "banana maçã" : 'pakova masã (Kaiowá)' ,
                "banana prata" : 'pakova pytã (Kaiowá)' ,
                "bacuri" : 'pakuri (Kaiowá)' ,
                "borboleta" : 'panambi (Kaiowá)' ,



                'cabeça':'nôçueri (Paresí) ou akag (tupi-guarani)',
                "casa": "oka (tupi)",
                'chuva':'amana ou Amanda (tupi antigo) ou munhâm (tupi-guarani)',
                'carro':'piaçava (tupi)',
                'cuida':'cuia ou dhui (tupi)',
                'curso':'tremembé ou Oiapoque ou jurubatuba(tupi)',
                'caipora':'caapuã(tupi)',
                'cabloco':'kariboka(tupi)',
                'cheio':'abiró ou bá(tupi)',
                'cocar':'acangatara(tupi)',
                'caju':'akaîu(tupi)',
                'centopeia':'ambûá(tupi)',
                'colo':'anhuri(tupi)',
                'coruja':'aondê(tupi)',
                'caminho':'apé(tupi)',
                'crespo':'apichai(tupi)',
                'chama':'ataendy(tupi)',
                'caranguejo':'auçá(tupi)',
                'catequista':'avaré(tupi)',
                'canta':'cê(tupi)',
                'carioca':'kari(Tupi-Guarani)',
                'cacau':'cacauatl (Náhuatle)',
                'caipira':'caaipura (Tupi-Guarani)',
                'Caatinga':'caá-t-enga (Tupi-Guarani)',
                'caiçara':'caá-içara (Tupi-Guarani)',
                'Capim':'caá (Tupi-Guarani) ou caapii (tupinambá)',
                'Capoeira':'co-poera (Tupi-Guarani)',
                'capivara':'kapiiguara (Tupi-Guarani)',
                'Catuaba':'caá (Tupi-Guarani)',
                'Cipó':'ici-fila (Tupi-Guarani)',
                'Copacabana':'kupa kawana (quechua)',
                'Cutia':'a-cuti (Tupi-Guarani)',
               'casa':'oka (tupi-guarani)',
                'cutucar':'kútuk (tupinambá)',
                'comida':'mangút (tupi-guarani)',
                'cacto':'jumbeba (tupi-guarani)',
                'curto':'aquitã (tupi-guarani)',
                'catapora':'tatapora (tupi)',
                'catupiry':'catupiri (tupi)',
                'cacau':'cacautl (nahuatl)',
              "conclusão" : "agwyje (kaiowá)",
                "caçula": 'pahagwe (Kaiowá)' ,



                'dente':'naikurí (Paresí)',
                "Dia" : 'dia chuvoso = Amanara(Tupi) ou Dia de chuva = Amandy(Tupi)',
                'Distante':'Anomatí(Tupi)',
                'Dor':'Acemira(Tupi)',
                'Duende':'Anãmiri(Tupi)',
                'Deusa' : 'deusa das águas = Yara(Tupi) ou Deusa da mandioca = Maní(Tupi)',
                'Deus' : 'deus do amor = Rudá(Tupi)',
                'Da mesma região':'Javaé(Tupi)',
                "descontar" : "ahéi (kaiowá)",



                "Ele": 'italá (Paresí)',
                "Esquecimento": "Eçaraia (tupi)",
                "enfraquecer" : "hato (Xavante)",
                "Enganar" : 'hapetse (Xavante)',
                "Elástico": ' ännhatä (Ye kwana)',
                "Emendar":'ichotontädö (Ye Kwana)',
                "Enchente":'chuumadö (Ye Kwana)',
                "Escada":"kadeeda (Ye Kwana)",
                "Escorpião":"mönäätä (Ye Kwana)",
                "Empurrado":" anhana (Tupi)",
                "Espinho":"Ju (Tupi)",
                "Estrela":"îasytatá(Tupi) ou wasi(Xavante)",
                "enforcar": 'aîubika (Tupi)' ,


                'falar':'Niaurí (Paresí) ou Nhe (Tupi) ou fala inteligente = Nanbiquara (Tupi) ou falação = Nhenhenhém (Tupi)',
                'fogo':'Tatá (Nheengatu) ou turi (Tupi)',
                'fogueira':'Turi (Tupi) ou Atagûasu (Tupi)',
                'felicidade':'Angatu (Tupi)',
                'face':'nuca-cuiá (Baniwa)',
                'floresta':'ka´a (Tupi) ou segredo na floresta = thiago (herói)',
                "forte" : "Antã ou Atã (Tupi)" ,
                "formosa" : "Aisó (Tupi)" ,
                "filha": " Aiyra (Tupi) ",
                "fruta": "com grande quantidade de vitamina = Camu-camu (Tupi)",
                "fruta":" com espinho = Ajuhá (Tupi) ou ma'ywa (Guajajara) ou  fruta verde = zusery (Apalaí) ou rob'rã (Xavanti)",
                "flor" : "Fulô (Tupi)",
                'farinha':'ma-tçoca (Baniwa)',
                'feio':'dôpo (Baniwa)',
                'frio':'a-pêrri (Baniwa)',
                'febre':'tacûa (Baniwa)',
                'furtar':'Naquin (Apinayé)',
                " finado":"Amyri (Tupi)",
                "faca":"cápa (Baniwa)",
                "formiga":"saúva (Tupi) ou hamé (Baniwa)",
                "fugir":"Jabá (Tupi)" ,
                'filho' : 'Membira (Tupi) ou Membyra (Tupi Antigo)' ,
                'folha' : 'Cáa (Tupi) ou folha jurubeba = ru (Tupi)',
                "fumaça":"Amerê (Tupi)" ,
                'flecha' : 'Pyrou (Apalaí) ou Crúa (Apinayé) ou Na (Kaingang)' ,
                'filho' : 'kósin (Kaingang)' ,
                'família': 'anama (Tupi)' ,
                'fantasma' : 'angoera (Tupi)' ,
                "feixe" : "apytama (Tupi)" ,
                "formiguinha" : 'aimirim (Tupi)' ,
                "formosa" : 'aisó (Tupi)' ,


                "gelo":"Yro'y (Tupi-guarani)",
                "golfinho":"Araranguá (tupi- guarani)",
                "garça":'Acará (tupi-guarani)',
                "galinha" :'takuirá (Paresí)',
                "guerreiro" : "Guariní (tupi-guarani)" ,
                "girassol" : "dasi'wapé (xavante)" ,
                "Gente" : "Abá (tupi-guarani)" ,
                "Garota" : "cunhantã (tupi-guarani)" ,
                "Garoto" : "Curumim (tupi-guarani)",
                "Grande":"Açu (Tupi)",
                "Grosso": "Anama (Tupi)",
                "Guaia (Caranguejo)": "Aauçá (Tupi)",
                "Guariba":"Wa'riwa (Tupi)",
                "Gato":"Yawara (Tupi)",
                "Girar":"Baka (Tupinambá)",
                "Gigante":"Abaçai (Tupinambá)",
                "Guerra":"Marana (Tupinambá)",
                "Gordura":"Kaba (Tupinambá)",
                "Grama":"Ka'a (Tupinambá)",
                "Gaivota":"Ati (Tupi) ou Gaivota grande = Atiati (Tupi)",
                "Gênio":"Yacamim (Tupi)",
                "Guerrear" : "tamambuê ahat ( Mawé)" ,
                "Gratidão" : "HA'EVEte (tupi-guarani)" ,
                "Grilo" : "kôxí (kaiapó)" ,
                "Guardar" : "tiçâa (kaiapó)" ,
                "Gritar" : "Asema (tupi-guarani)" ,
                 "gordo": 'abirú (Tupi) ' ,
                 "graveto": 'akãi (Tupi)' ,


                'homem':'ená (Paresí) ou Atuá ou Abá (Tupi) ou kariay (kaiwá) ou Homem verdadeiro = Abaeté (Tupi) ou homem que voa = Abaquar (Tupi) ou homem do mato = cambé (tupi) ou homem branco = Cari (Tupi)',
                'hoje': 'cuitirí (guajajara)',
                'honrado':'etê (tupi)',
                'humano': 'maajaama (yekwana)',


                'ir':'iantá (Paresí)',
                'imprestável':'Iua',
                'Iba': 'Iwa (tupi-guarani)',
                'Indivíduo':'Indivíduo de peito negro = jacaúna (tupi-guarani) ou indivíduo atarracado = Caburé (tupi)',
                'índio':'Abá ou Avá ou Auá (tupi-guarani)',
                'Igreja':'tupao (tupi-guarani)',
                'Idioma':'damreme (Xavante)',
                'inteiramente':'ejete (tupi)',
                'intervalo':'ai-ai (tupi)',
                'inquieto':'ara-á (tupi)',
                'ibirapuera' : 'ibirá-puera (Tupi-Guarani)' ,
                "intervalo" : 'pa ũ (Kaiowá)' ,


                'jandaia':'kuíri (Paresí)',
                'Jerimum':'Yurumún (Tupi-guarani)',
                'Jiboia':'Jy (Tupi-guarani)',
                'Jabuti':'Karumbe (Tupi-Guarani)',
                'Jaca':'Kavaju (Tupi-Guarani)',
                'Joelho':'Penarã (Tupi-Guarani)',
                'jacaré':'jarça',
                'Junto':'Âguĩ (Tupi-Guarani)',
                'Janeiro':'Jasyteĩ (Tupi-Guarani)',
                'jesus':'Hesu',
                'Jovem':'Cururim (Tupi-Guarani)',
                'Janta':'Cená ou Karu (Tupi-Guarani)',
                'Jangada':'Igapeba (Tupi-Guarani)',
                'Jogar':'Temamián (Tupi-Guarani)',
                'Judiar':'Tinaprê (Tupi-Guarani)',

                'katipé (árvore)':'uhiça (Paresí)',


                'luz':'mentuktire (Tupi)',

                'mãe':'mamá ou amá (Paresí) ou sy (Tupi antigo)',
                'mar':'paranã (Tupi antigo)',
                'Moça':'Zuimáhalutí (Paresí)',
                'Morro':'Zaúna (Paresí)',
                'Mosquito':'Zaúna (Paresí)',
                'Mingau de mandioca':'Katazeurê (Paresí)',
                'Mingau de milho':'Kamulazá (Paresí)',
                'Milho':'Abati (Tupi-Guarani)',
                'mensageiro':'Amanajé (Tupi-Guarani)',
                'morcego':'Andirá',
                'marimbondo':'Caba (Tupi-Guarani)',
                'mel':'Ira (Tupi-Guarani)',
                'Maracanã':'paracau-aná (Tupi-Guarani)',
                'Mingau':'mi-caú (Tupi-Guarani)',
                'Mocotó':'mo-coto (Tupi-Guarani)',
                'Mutirão':'pitibõ ou popitibõ ou picorõ (Tupi-Guarani)',
                'Mutum':'plumagem (Tupi-Guarani)',
                'Monte de conchas':'Tambakï (Tupi)',
                'Moqueca':'Pokeka (Tupi)',
                'Macaco':'Sagüi (Tupi-Guarani)',
                'Mestiço':'Mamai-ruuca (Tupi-Guarani)',
                'Mãe dágua':'Yara (Tupi)',
                "manca" : 'parĩ (Kaiowá)',
                 "mensageiro": 'amanajé (Tupi)' ,


                'nariz':'nhãpynha (Kawahiva)',
                'não':'maiçá (Paresí) ou Ñiá (Tupi-guarani)',
                'Nós':'íandé(tupi antigo)',
                'Nevoeiro':'ibitinga(Tupi-guarani)',
                'Nuvem':'uaaté (Tupi-guarani)',
                'ninho':'Araraquara (Tupi) ou Ayty (Tupi)',
                'nascer':'nascer do dia = Aracê (Tupi)',
                'noite':'Pituna (Tupi) ou yputuna (Kawahiva) ',
                'nômade':'goitacá (Kawahiva) ',
                'nuca' :'jirypya (Kawahiva) ',
                "nuvem" : 'paráry (Kaiowá)' ,
                "noivo" : 'abaíba (Tupi) ' ,


                'olho de boi':'onoê (Paresí)',
                'onça-hu' :'(xavante)',
                'oka':'casa de indio v.ocara, manioca ( Tupi)',
                'onça':'jini (Tupi) Auiató (Mawé)',
                'ore':'caçar animais pequenos (Tupi)',
                'OI/OLÁ':'anauê (Tupi)',
                'Olho':'Oheha (Mawé)',
                'Orelha':'Uihapê (Mawé)',
                'Ontem':'Nhaatpó (Mawé)',



                "pedra": 'ita (Tupi)',
                'pai' : 'damama (Xavante) ou tuba (Tupi antigo)' ,
                'papagaio' : 'waihârâ (Xavante) ou azuru (Guajajara)' ,
                'peixe' : 'pirá (Tupi antigo) ou arumaxi (apalaí)' ,
                'pequeno' : 'mirim (Tupi antigo)',
                "papagaio" : 'parakáu (Kaiowá)' ,
                "pacu" : 'paku (Kaiowá)' ,


                'quina':'ahonlê (Paresí)',

                'rede':'maká (Paresí)',

                "Sol" : "kûarasy (Tupi)",
                "sabiá": 's-apia ( tupi)' ,
                "saci-perere" : 'çá-aci (tupi)',
                "Sonhar": 'Aquahú (Guajajara)',
                "Sim": 'Eré (Guajajara)',
                'Sujo': 'Kiá (nheengatu)',
                "Sítio" : "Tendaua (nheengatu)",
                "Sentar" :'Duhicé (Tucana)',
                "Soprar" : 'Pukticé (Tucana)',
                'Surdo' : 'Çampanón (Kaiapo)',
                'Sumir':'Itó (Kaiapo)',
                'Saber':'Epu`tî (Makuxi)',
                'Sair': 'Anrîmaka (Makuxi)',
                'Sincero': 'Etê (Tupi)',
                'Seio': 'Camb (Tupi)',


                'terra':'uaikôen (Paresí)',


                'urubu':'olohôn (Paresí)',
                "última": 'kaiowá (Kaiowá)',


                'veneno':'zamarí (Paresí)',


                "quando": 'tikat (Karitiána)',
                "quatro": 'otadnamynt (Tupi)',
                "queimar": 'pipop (Tupi)',
                "quem": "morã (Tupi) ou mobo (Karajá)",











                "sacerdote" : ' pa i (Kaiowá)',
                "xamã" :'Pa i Jirutipu (Kaiowá)',
                "sol" : 'Pa i Kwara (Kaiowá)' ,
                "descendente" : 'paĩ (Kaiowá)' ,
                "líder espiritual" : 'pa i hechakáry (Kaiowá)' ,
                "girassol" : 'paĩ poty (Kaiowá)' ,
                "inferno" : 'pa i rei (Kaiowá)' ,
                "mar" : 'para (Kaiowá)' ,










}
palavra = input("Digite Palavra em portugues: ")
if palavra in dic_indigena:
  valor = dic_indigena[palavra]
  print("A correspondencia à palavra", palavra, "é", valor)
else:
  print("Desculpe, ainda não catalogamos esta palavra.")
#Buscando valor com base na chave
#if palavra == dic_indigena.get(input("Digite a palavra em portugues: ")):
#if palavra == dic_indígena:
#  print(palavra)
#else:  # Está linha de código para informar que não temos a palavra
#  print('Desculpe, ainda não catalogamos esta palavra')
# Out:
# Digite Palavra em portugues: amar
# A correspondencia à palavra amar é hayhu (Paresí) ou uzamutar (Guajajara)

# %%
# O primeiro valor é a palavra em português e o segundo indígena

dic_indigena = {'amar': 'hayhu (Paresí) ou uzamutar (Guajajara) ',
                "alma" : 'anhang (Tupi) ' ,
                "água": 'y ou ty (Tupi) ou â (Xavante) outuna (Apalaí)  ou Água funda = ârehâ (Xavante) ou Água parada = u (Xavante) ou Água adoçada = âze (Xavante)',
                "aracanguira" : 'abacataia ou Abacatuia (Tupi)',
                "amigo" : "amigo de roupa preta = Abaruna (Tupi) ou amigo dos papagaios = Ararê (Tupi)",
                "ave" : "ave branca = Acará (Tupi)",
                "amarelo": 'Ajubá',
                "Árvore": "aramari apo (Apalaí) ou atya (paresi-haliti) ou árvore de madeira dura = Ajuru (Tupi)",
                "anão":'Anãmiri (Tupi)',
                "acamim": 'Iacamim (Tupi)',
                "açaí": 'Uaçai ou yasaí (Tupi)',
                "arara": 'A rara (Tupi)',
                "abelha":'Arapuá (Tupi)',
                "Anta":'Tapir(Tupi)',
                "Abondonado":'Ītu(Xavante)',
                "Acertar":'Japete(Tupi)',
                "Aconselhar":'Wada uri(Xavante)',
                "amigo":'amigo dos papagaios(Tupi)',
                "abundância" : "orévy(kaiowá)",
                "agradecimento" : "agwyjeme'e (kaiowá)",


                "beber":" `u ( tupinambá)",
                "boca":"a,chau-a (tikúna)",
                "bravo":"acê (kaipó)",
                "braço (o)":"agnipcaton (pataxó)",
                "brilhbar":"niongnitochingá (pataxó)",
                "barba":"aivánindivá (apiacá)",
                "bonito":"porang (tupi)",
                "bom":"katu (tupi)",
                "brilhante":"beraba (eburiini)",
                "Baiacu":"mbaéacu (tupi)",
                "Bauru":"upaurú (tupi)",
                "Biboca":"ymby mbóka (Tupi)",
                "banana" : 'pakova (Kaiowá)' ,
                "banana nanica" : 'pakova karape (Kaiowá)' ,
                "banana maçã" : 'pakova masã (Kaiowá)' ,
                "banana prata" : 'pakova pytã (Kaiowá)' ,
                "bacuri" : 'pakuri (Kaiowá)' ,
                "borboleta" : 'panambi (Kaiowá)' ,



                'cabeça':'nôçueri (Paresí) ou akag (tupi-guarani)',
                "casa": "oka (tupi)",
                'chuva':'amana ou Amanda (tupi antigo) ou munhâm (tupi-guarani)',
                'carro':'piaçava (tupi)',
                'cuida':'cuia ou dhui (tupi)',
                'curso':'tremembé ou Oiapoque ou jurubatuba(tupi)',
                'caipora':'caapuã(tupi)',
                'cabloco':'kariboka(tupi)',
                'cheio':'abiró ou bá(tupi)',
                'cocar':'acangatara(tupi)',
                'caju':'akaîu(tupi)',
                'centopeia':'ambûá(tupi)',
                'colo':'anhuri(tupi)',
                'coruja':'aondê(tupi)',
                'caminho':'apé(tupi)',
                'crespo':'apichai(tupi)',
                'chama':'ataendy(tupi)',
                'caranguejo':'auçá(tupi)',
                'catequista':'avaré(tupi)',
                'canta':'cê(tupi)',
                'carioca':'kari(Tupi-Guarani)',
                'cacau':'cacauatl (Náhuatle)',
                'caipira':'caaipura (Tupi-Guarani)',
                'Caatinga':'caá-t-enga (Tupi-Guarani)',
                'caiçara':'caá-içara (Tupi-Guarani)',
                'capim':'caá (Tupi-Guarani) ou caapii (tupinambá)',
                'capoeira':'co-poera (Tupi-Guarani)',
                'capivara':'kapiiguara (Tupi-Guarani)',
                'catuaba':'caá (Tupi-Guarani)',
                'cipó':'ici-fila (Tupi-Guarani)',
                'copacabana':'kupa kawana (quechua)',
                'cutia':'a-cuti (Tupi-Guarani)',
               'casa':'oka (tupi-guarani)',
                'cutucar':'kútuk (tupinambá)',
                'comida':'mangút (tupi-guarani)',
                'cacto':'jumbeba (tupi-guarani)',
                'curto':'aquitã (tupi-guarani)',
                'catapora':'tatapora (tupi)',
                'catupiry':'catupiri (tupi)',
                'cacau':'cacautl (nahuatl)',
                "conclusão" : "agwyje (kaiowá)",
                'conclusão' : 'agwyje (kaiowá)',
                'chapéu' : 'akā aho iha (kaiowá) ',


                'dente':'naikurí (Paresí)',
                "dia" : 'dia chuvoso = Amanara(Tupi) ou Dia de chuva = Amandy(Tupi)',
                'distante':'Anomatí(Tupi)',
                'dor':'Acemira(Tupi)',
                'duende':'Anãmiri(Tupi)',
                'deusa' : 'deusa das águas = Yara(Tupi) ou Deusa da mandioca = Maní(Tupi)',
                'deus' : 'deus do amor = Rudá(Tupi)',
                'da mesma região':'Javaé(Tupi)',
                "descontar" : "ahéi (kaiowá)",
                'daqui' : 'ágwi (kaiowá)',
                'depilar' : '(o-h)agwe o (kaiowá)',




                "ele": 'italá (Paresí)',
                "enfraquecer" : "hato (Xavante)",
                "enganar" : 'hapetse (Xavante)',
                "elástico": ' ännhatä (Ye kwana)',
                "emendar":'ichotontädö (Ye Kwana)',
                "enchente":'chuumadö (Ye Kwana)',
                "escada":"kadeeda (Ye Kwana)",
                "escorpião":"mönäätä (Ye Kwana)",
                "empurrado":" anhana (Tupi)",
                "espinho":"Ju (Tupi)",
                "estrela":"îasytatá(Tupi) ou wasi(Xavante)",
                "esquecimento": "Eçaraia (tupi)",
                'encolhido' : 'akhra a (kaiowá)',


                'falar':'Niaurí (Paresí) ou Nhe (Tupi) ou fala inteligente = Nanbiquara (Tupi) ou falação = Nhenhenhém (Tupi)',
                'fogo':'Tatá (Nheengatu) ou turi (Tupi)',
                'fogueira':'Turi (Tupi) ou Atagûasu (Tupi)',
                'felicidade':'Angatu (Tupi)',
                'face':'nuca-cuiá (Baniwa)',
                "forte" : "Antã ou Atã (Tupi)" ,
                "formosa" : "Aisó (Tupi)" ,
                "filha": " Aiyra (Tupi) ",
                "fruta": "com grande quantidade de vitamina = Camu-camu (Tupi)",
                "fruta":" com espinho = Ajuhá (Tupi) ou ma'ywa (Guajajara) ou  fruta verde = zusery (Apalaí) ou rob'rã (Xavanti)",
                "flor" : "Fulô (Tupi)",
                'farinha':'ma-tçoca (Baniwa)',
                'feio':'dôpo (Baniwa)',
                'frio':'a-pêrri (Baniwa)',
                'febre':'tacûa (Baniwa)',
                'furtar':'Naquin (Apinayé)',
                " finado":"Amyri (Tupi)",
                "faca":"cápa (Baniwa)",
                "formiga":"saúva (Tupi) ou hamé (Baniwa)",
                "fugir":"Jabá (Tupi)" ,
                'filho' : 'Membira (Tupi) ou Membyra (Tupi Antigo)' , 'kósin (Kaingang)' ,
                'folha' : 'Cáa (Tupi) ou folha jurubeba = ru (Tupi)',
                "fumaça":"Amerê (Tupi)" ,
                'flecha' : 'Pyrou (Apalaí) ou Crúa (Apinayé) ou Na (Kaingang)' ,
                'família': 'anama (Tupi)' ,
                'fantasma' : 'angoera (Tupi)' ,
                "feixe" : "apytama (Tupi)" ,
                "formiguinha" : 'aimirim (Tupi)' ,
                "formosa" : 'aisó (Tupi)' ,



                "gelo":"Yro'y (Tupi-guarani)",
                "golfinho":"Araranguá (tupi- guarani)",
                "garça":'Acará (tupi-guarani)',
                "galinha" :'takuirá (Paresí)',
                "guerreiro" : "Guariní (tupi-guarani)" ,
                "girassol" : "dasi'wapé (xavante)" ,
                "gente" : "Abá (tupi-guarani)" ,
                "garota" : "cunhantã (tupi-guarani)" ,
                "garoto" : "Curumim (tupi-guarani)",
                "grande":"Açu (Tupi)",
                "grosso": "Anama (Tupi)",
                "guaia (Caranguejo)": "Aauçá (Tupi)",
                "guariba":"Wa'riwa (Tupi)",
                "gato":"Yawara (Tupi)",
                "girar":"Baka (Tupinambá)",
                "gigante":"Abaçai (Tupinambá)",
                "guerra":"Marana (Tupinambá)",
                "gordura":"Kaba (Tupinambá)",
                "grama":"Ka'a (Tupinambá)",
                "gaivota":"Ati (Tupi) ou Gaivota grande = Atiati (Tupi)",
                "gênio":"Yacamim (Tupi)",
                "guerrear" : "tamambuê ahat ( Mawé)" ,
                "gratidão" : "HA'EVEte (tupi-guarani)" ,
                "grilo" : "kôxí (kaiapó)" ,
                "guardar" : "tiçâa (kaiapó)" ,
                "gritar" : "Asema (tupi-guarani)" ,
                 "gordo": 'abirú (Tupi) ' ,
                'garoa' : 'amandayvi (kaiowá)',
                'garganta' : 'ahy o (kaiowá)',
                'genro' : 'iñj (kaiowá)',



                'homem':'ená (Paresí) ou Atuá ou Abá (Tupi) ou kariay (kaiwá) ou Homem verdadeiro = Abaeté (Tupi) ou homem que voa = Abaquar (Tupi) ou homem do mato = cambé (tupi) ou homem branco = Cari (Tupi)',
                'hoje': 'cuitirí (guajajara)',
                'honrado':'etê (tupi)',
                'humano': 'maajaama (yekwana)',


                'ir':'iantá (Paresí)',
                'imprestável':'Iua',
                'iba': 'Iwa (tupi-guarani)',
                'indivíduo':'Indivíduo de peito negro = jacaúna (tupi-guarani) ou indivíduo atarracado = Caburé (tupi)',
                'índio':'Abá ou Avá ou Auá (tupi-guarani)',
                'igreja':'tupao (tupi-guarani)',
                'idioma':'damreme (Xavante)',
                'inteiramente':'ejete (tupi)',
                'intervalo':'ai-ai (tupi)',
                'inquieto':'ara-á (tupi)',
                'ibirapuera' : 'ibirá-puera (Tupi-Guarani)' ,
                "intervalo" : 'pa ũ (Kaiowá)' ,


                'jandaia':'kuíri (Paresí)',
                'jerimum':'Yurumún (Tupi-guarani)',
                'jiboia':'Jy (Tupi-guarani)',
                'jabuti':'Karumbe (Tupi-Guarani)',
                'jaca':'Kavaju (Tupi-Guarani)',
                'joelho':'Penarã (Tupi-Guarani)',
                'junto':'Âguĩ (Tupi-Guarani)',
                'janeiro':'Jasyteĩ (Tupi-Guarani)',
                'jovem':'Cururim (Tupi-Guarani)',
                'janta':'Cená ou Karu (Tupi-Guarani)',
                'jangada':'Igapeba (Tupi-Guarani)',
                'jogar':'Temamián (Tupi-Guarani)',
                'judiar':'Tinaprê (Tupi-Guarani)',
                'jaçanã' : 'agwapeaso (kaiowá)',


                'katipé (árvore)':'uhiça (Paresí)',


                'luz':'mentuktire (Tupi)',

                'mãe':'mamá ou amá (Paresí) ou sy (Tupi antigo)',
                'mar':'paranã (Tupi antigo)',
                'Moça':'Zuimáhalutí (Paresí)',
                'Morro':'Zaúna (Paresí)',
                'Mosquito':'Zaúna (Paresí)',
                'Mingau de mandioca':'Katazeurê (Paresí)',
                'Mingau de milho':'Kamulazá (Paresí)',
                'Milho':'Abati (Tupi-Guarani)',
                'mensageiro':'Amanajé (Tupi-Guarani)',
                'morcego':'Andirá',
                'marimbondo':'Caba (Tupi-Guarani)',
                'mel':'Ira (Tupi-Guarani)',
                'Maracanã':'paracau-aná (Tupi-Guarani)',
                'Mingau':'mi-caú (Tupi-Guarani)',
                'Mocotó':'mo-coto (Tupi-Guarani)',
                'Mutirão':'pitibõ ou popitibõ ou picorõ (Tupi-Guarani)',
                'Mutum':'plumagem (Tupi-Guarani)',
                'Monte de conchas':'Tambakï (Tupi)',
                'Moqueca':'Pokeka (Tupi)',
                'Macaco':'Sagüi (Tupi-Guarani)',
                'Mestiço':'Mamai-ruuca (Tupi-Guarani)',
                'Mãe dágua':'Yara (Tupi)',
                "manca" : 'parĩ (Kaiowá)',


                'nariz':'nhãpynha (Kawahiva)',
                'não':'maiçá (Paresí) ou Ñiá (Tupi-guarani)',
                'Nós':'íandé(tupi antigo)',
                'Nevoeiro':'ibitinga(Tupi-guarani)',
                'Nuvem':'uaaté (Tupi-guarani)',
                'ninho':'Araraquara (Tupi) ou Ayty (Tupi)',
                'nascer':'nascer do dia = Aracê (Tupi)',
                'noite':'Pituna (Tupi) ou yputuna (Kawahiva) ',
                'nômade':'goitacá (Kawahiva) ',
                'nuca' :'jirypya (Kawahiva) ',
                "nuvem" : 'paráry (Kaiowá)' ,
                "noivo" : 'abaíba (Tupi) ' ,


                'olho de boi':'onoê (Paresí)',
                'onça-hu' :'(xavante)',
                'oka':'casa de indio v.ocara, manioca ( Tupi)',
                'onça':'jini (Tupi) Auiató (Mawé)',
                'ore':'caçar animais pequenos (Tupi)',
                'OI/OLÁ':'anauê (Tupi)',
                'Olho':'Oheha (Mawé)',
                'Orelha':'Uihapê (Mawé)',
                'Ontem':'Nhaatpó (Mawé)',



                "pedra": 'ita (Tupi)',
                'pai' : 'damama (Xavante) ou tuba (Tupi antigo)' ,
                'papagaio' : 'waihârâ (Xavante) ou azuru (Guajajara)' ,
                'peixe' : 'pirá (Tupi antigo) ou arumaxi (apalaí)' ,
                'pequeno' : 'mirim (Tupi antigo)',
                "papagaio" : 'parakáu (Kaiowá)' ,
                "pacu" : 'paku (Kaiowá)' ,


                'quina':'ahonlê (Paresí)',

                'rede':'maká (Paresí)',

                "Sol" : "kûarasy (Tupi)",
                "sabiá": 's-apia ( tupi)' ,
                "saci-perere" : 'çá-aci (tupi)',
                "Sonhar": 'Aquahú (Guajajara)',
                "Sim": 'Eré (Guajajara)',
                'Sujo': 'Kiá (nheengatu)',
                "Sítio" : "Tendaua (nheengatu)",
                "Sentar" :'Duhicé (Tucana)',
                "Soprar" : 'Pukticé (Tucana)',
                'Surdo' : 'Çampanón (Kaiapo)',
                'Sumir':'Itó (Kaiapo)',
                'Saber':'Epu`tî (Makuxi)',
                'Sair': 'Anrîmaka (Makuxi)',
                'Sincero': 'Etê (Tupi)',
                'Seio': 'Camb (Tupi)',


                'terra':'uaikôen (Paresí)',


                'urubu':'olohôn (Paresí)',


                'veneno':'zamarí (Paresí)',


                "quando": 'tikat (Karitiána)',
                "quatro": 'otadnamynt (Tupi)',
                "queimar": 'pipop (Tupi)',
                "quem": "morã (Tupi) ou mobo (Karajá)",






                "enforcar": 'aîubika (Tupi)' ,
                "graveto": 'akãi (Tupi)' ,
                "mensageiro": 'amanajé (Tupi)' ,
                "última": 'kaiowá (Kaiowá)',
                "caçula": 'pahagwe (Kaiowá)' ,
                "sacerdote" : ' pa i (Kaiowá)',
                "xamã" :'Pa i Jirutipu (Kaiowá)',
                "sol" : 'Pa i Kwara (Kaiowá)' ,
                "descendente" : 'paĩ (Kaiowá)' ,
                "líder espiritual" : 'pa i hechakáry (Kaiowá)' ,
                "girassol" : 'paĩ poty (Kaiowá)' ,
                "inferno" : 'pa i rei (Kaiowá)' ,
                "mar" : 'para (Kaiowá)' ,










}
palavra = input("Digite Palavra em portugues: ")
if palavra in dic_indigena:
  valor = dic_indigena[palavra]
  print("A correspondencia à palavra", palavra, "é", valor)
else:
  print("Desculpe, ainda não catalogamos esta palavra.")
#Buscando valor com base na chave
#if palavra == dic_indigena.get(input("Digite a palavra em portugues: ")):
#if palavra == dic_indígena:
#  print(palavra)
#else:  # Está linha de código para informar que não temos a palavra
#  print('Desculpe, ainda não catalogamos esta palavra')

# %%
# O primeiro valor é a palavra em português e o segundo indígena

dic_indigena = {'amar': 'hayhu (Paresí) ou uzamutar (Guajajara) ',
                "alma" : 'anhang (Tupi) ' ,
                "água": 'y ou ty (Tupi) ou â (Xavante) outuna (Apalaí)  ou Água funda = ârehâ (Xavante) ou Água parada = u (Xavante) ou Água adoçada = âze (Xavante)',
                "aracanguira" : 'abacataia ou Abacatuia (Tupi)',
                "amigo" : "amigo de roupa preta = Abaruna (Tupi) ou amigo dos papagaios = Ararê (Tupi)",
                "ave" : "ave branca = Acará (Tupi)",
                "amarelo": 'Ajubá',
                "Árvore": "aramari apo (Apalaí) ou atya (paresi-haliti) ou árvore de madeira dura = Ajuru (Tupi)",
                "anão":'Anãmiri (Tupi)',
                "acamim": 'Iacamim (Tupi)',
                "açaí": 'Uaçai ou yasaí (Tupi)',
                "arara": 'A rara (Tupi)',
                "abelha":'Arapuá (Tupi)',
                "Anta":'Tapir(Tupi)',
                "Abondonado":'Ītu(Xavante)',
                "Acertar":'Japete(Tupi)',
                "Aconselhar":'Wada uri(Xavante)',
                "amigo":'amigo dos papagaios(Tupi)',
                "abundância" : "orévy(kaiowá)",
                "agradecimento" : "agwyjeme'e (kaiowá)",


                "beber":" `u ( tupinambá)",
                "boca":"a,chau-a (tikúna)",
                "bravo":"acê (kaipó)",
                "braço (o)":"agnipcaton (pataxó)",
                "brilhbar":"niongnitochingá (pataxó)",
                "barba":"aivánindivá (apiacá)",
                "bonito":"porang (tupi)",
                "bom":"katu (tupi)",
                "brilhante":"beraba (eburiini)",
                "Baiacu":"mbaéacu (tupi)",
                "Bauru":"upaurú (tupi)",
                "Biboca":"ymby mbóka (Tupi)",
                "banana" : 'pakova (Kaiowá)' ,
                "banana nanica" : 'pakova karape (Kaiowá)' ,
                "banana maçã" : 'pakova masã (Kaiowá)' ,
                "banana prata" : 'pakova pytã (Kaiowá)' ,
                "bacuri" : 'pakuri (Kaiowá)' ,
                "borboleta" : 'panambi (Kaiowá)' ,



                'cabeça':'nôçueri (Paresí) ou akag (tupi-guarani)',
                "casa": "oka (tupi)",
                'chuva':'amana ou Amanda (tupi antigo) ou munhâm (tupi-guarani)',
                'carro':'piaçava (tupi)',
                'cuida':'cuia ou dhui (tupi)',
                'curso':'tremembé ou Oiapoque ou jurubatuba(tupi)',
                'caipora':'caapuã(tupi)',
                'cabloco':'kariboka(tupi)',
                'cheio':'abiró ou bá(tupi)',
                'cocar':'acangatara(tupi)',
                'caju':'akaîu(tupi)',
                'centopeia':'ambûá(tupi)',
                'colo':'anhuri(tupi)',
                'coruja':'aondê(tupi)',
                'caminho':'apé(tupi)',
                'crespo':'apichai(tupi)',
                'chama':'ataendy(tupi)',
                'caranguejo':'auçá(tupi)',
                'catequista':'avaré(tupi)',
                'canta':'cê(tupi)',
                'carioca':'kari(Tupi-Guarani)',
                'cacau':'cacauatl (Náhuatle)',
                'caipira':'caaipura (Tupi-Guarani)',
                'Caatinga':'caá-t-enga (Tupi-Guarani)',
                'caiçara':'caá-içara (Tupi-Guarani)',
                'Capim':'caá (Tupi-Guarani) ou caapii (tupinambá)',
                'Capoeira':'co-poera (Tupi-Guarani)',
                'capivara':'kapiiguara (Tupi-Guarani)',
                'Catuaba':'caá (Tupi-Guarani)',
                'Cipó':'ici-fila (Tupi-Guarani)',
                'Copacabana':'kupa kawana (quechua)',
                'Cutia':'a-cuti (Tupi-Guarani)',
               'casa':'oka (tupi-guarani)',
                'cutucar':'kútuk (tupinambá)',
                'comida':'mangút (tupi-guarani)',
                'cacto':'jumbeba (tupi-guarani)',
                'curto':'aquitã (tupi-guarani)',
                'catapora':'tatapora (tupi)',
                'catupiry':'catupiri (tupi)',
                'cacau':'cacautl (nahuatl)',
              "conclusão" : "agwyje (kaiowá)",



                'dente':'naikurí (Paresí)',
                "Dia" : 'dia chuvoso = Amanara(Tupi) ou Dia de chuva = Amandy(Tupi)',
                'Distante':'Anomatí(Tupi)',
                'Dor':'Acemira(Tupi)',
                'Duende':'Anãmiri(Tupi)',
                'Deusa' : 'deusa das águas = Yara(Tupi) ou Deusa da mandioca = Maní(Tupi)',
                'Deus' : 'deus do amor = Rudá(Tupi)',
                'Da mesma região':'Javaé(Tupi)',
                "descontar" : "ahéi (kaiowá)",



                "Ele": 'italá (Paresí)',
                "Esquecimento": "Eçaraia (tupi)",
                "enfraquecer" : "hato (Xavante)",
                "Enganar" : 'hapetse (Xavante)',
                "Elástico": ' ännhatä (Ye kwana)',
                "Emendar":'ichotontädö (Ye Kwana)',
                "Enchente":'chuumadö (Ye Kwana)',
                "Escada":"kadeeda (Ye Kwana)",
                "Escorpião":"mönäätä (Ye Kwana)",
                "Empurrado":" anhana (Tupi)",
                "Espinho":"Ju (Tupi)",
                "Estrela":"îasytatá(Tupi) ou wasi(Xavante)",


                'falar':'Niaurí (Paresí) ou Nhe (Tupi) ou fala inteligente = Nanbiquara (Tupi) ou falação = Nhenhenhém (Tupi)',
                'fogo':'Tatá (Nheengatu) ou turi (Tupi)',
                'fogueira':'Turi (Tupi) ou Atagûasu (Tupi)',
                'felicidade':'Angatu (Tupi)',
                'face':'nuca-cuiá (Baniwa)',
                'floresta':'ka´a (Tupi) ou segredo na floresta = thiago (herói)',
                "forte" : "Antã ou Atã (Tupi)" ,
                "formosa" : "Aisó (Tupi)" ,
                "filha": " Aiyra (Tupi) ",
                "fruta": "com grande quantidade de vitamina = Camu-camu (Tupi)",
                "fruta":" com espinho = Ajuhá (Tupi) ou ma'ywa (Guajajara) ou  fruta verde = zusery (Apalaí) ou rob'rã (Xavanti)",
                "flor" : "Fulô (Tupi)",
                'farinha':'ma-tçoca (Baniwa)',
                'feio':'dôpo (Baniwa)',
                'frio':'a-pêrri (Baniwa)',
                'febre':'tacûa (Baniwa)',
                'furtar':'Naquin (Apinayé)',
                " finado":"Amyri (Tupi)",
                "faca":"cápa (Baniwa)",
                "formiga":"saúva (Tupi) ou hamé (Baniwa)",
                "fugir":"Jabá (Tupi)" ,
                'filho' : 'Membira (Tupi) ou Membyra (Tupi Antigo)' ,
                'folha' : 'Cáa (Tupi) ou folha jurubeba = ru (Tupi)',
                "fumaça":"Amerê (Tupi)" ,
                'flecha' : 'Pyrou (Apalaí) ou Crúa (Apinayé) ou Na (Kaingang)' ,
                'filho' : 'kósin (Kaingang)' ,
                'família': 'anama (Tupi)' ,
                'fantasma' : 'angoera (Tupi)' ,
                "feixe" : "apytama (Tupi)" ,
                "formiguinha" : 'aimirim (Tupi)' ,
                "formosa" : 'aisó (Tupi)' ,


                "gelo":"Yro'y (Tupi-guarani)",
                "golfinho":"Araranguá (tupi- guarani)",
                "garça":'Acará (tupi-guarani)',
                "galinha" :'takuirá (Paresí)',
                "guerreiro" : "Guariní (tupi-guarani)" ,
                "girassol" : "dasi'wapé (xavante)" ,
                "Gente" : "Abá (tupi-guarani)" ,
                "Garota" : "cunhantã (tupi-guarani)" ,
                "Garoto" : "Curumim (tupi-guarani)",
                "Grande":"Açu (Tupi)",
                "Grosso": "Anama (Tupi)",
                "Guaia (Caranguejo)": "Aauçá (Tupi)",
                "Guariba":"Wa'riwa (Tupi)",
                "Gato":"Yawara (Tupi)",
                "Girar":"Baka (Tupinambá)",
                "Gigante":"Abaçai (Tupinambá)",
                "Guerra":"Marana (Tupinambá)",
                "Gordura":"Kaba (Tupinambá)",
                "Grama":"Ka'a (Tupinambá)",
                "Gaivota":"Ati (Tupi) ou Gaivota grande = Atiati (Tupi)",
                "Gênio":"Yacamim (Tupi)",
                "Guerrear" : "tamambuê ahat ( Mawé)" ,
                "Gratidão" : "HA'EVEte (tupi-guarani)" ,
                "Grilo" : "kôxí (kaiapó)" ,
                "Guardar" : "tiçâa (kaiapó)" ,
                "Gritar" : "Asema (tupi-guarani)" ,


                'homem':'ená (Paresí) ou Atuá ou Abá (Tupi) ou kariay (kaiwá) ou Homem verdadeiro = Abaeté (Tupi) ou homem que voa = Abaquar (Tupi) ou homem do mato = cambé (tupi) ou homem branco = Cari (Tupi)',
                'hoje': 'cuitirí (guajajara)',
                'honrado':'etê (tupi)',
                'humano': 'maajaama (yekwana)',


                'ir':'iantá (Paresí)',
                'imprestável':'Iua',
                'Iba': 'Iwa (tupi-guarani)',
                'Indivíduo':'Indivíduo de peito negro = jacaúna (tupi-guarani) ou indivíduo atarracado = Caburé (tupi)',
                'índio':'Abá ou Avá ou Auá (tupi-guarani)',
                'Igreja':'tupao (tupi-guarani)',
                'Idioma':'damreme (Xavante)',
                'inteiramente':'ejete (tupi)',
                'intervalo':'ai-ai (tupi)',
                'inquieto':'ara-á (tupi)',
                'ibirapuera' : 'ibirá-puera (Tupi-Guarani)' ,
                "intervalo" : 'pa ũ (Kaiowá)' ,


                'jandaia':'kuíri (Paresí)',
                'Jerimum':'Yurumún (Tupi-guarani)',
                'Jiboia':'Jy (Tupi-guarani)',
                'Jabuti':'Karumbe (Tupi-Guarani)',
                'Jaca':'Kavaju (Tupi-Guarani)',
                'Joelho':'Penarã (Tupi-Guarani)',
                'jacaré':'jarça',
                'Junto':'Âguĩ (Tupi-Guarani)',
                'Janeiro':'Jasyteĩ (Tupi-Guarani)',
                'jesus':'Hesu',
                'Jovem':'Cururim (Tupi-Guarani)',
                'Janta':'Cená ou Karu (Tupi-Guarani)',
                'Jangada':'Igapeba (Tupi-Guarani)',
                'Jogar':'Temamián (Tupi-Guarani)',
                'Judiar':'Tinaprê (Tupi-Guarani)',

                'katipé (árvore)':'uhiça (Paresí)',


                'luz':'mentuktire (Tupi)',
                'lobo-guará' : 'agwara (kaiowá)',


                'mãe':'mamá ou amá (Paresí) ou sy (Tupi antigo)',
                'muito obrigado' : 'agwjevete (kaiowá)',
                'mar':'paranã (Tupi antigo)',
                'Moça':'Zuimáhalutí (Paresí)',
                'Morro':'Zaúna (Paresí)',
                'Mosquito':'Zaúna (Paresí)',
                'Mingau de mandioca':'Katazeurê (Paresí)',
                'Mingau de milho':'Kamulazá (Paresí)',
                'Milho':'Abati (Tupi-Guarani)',
                'mensageiro':'Amanajé (Tupi-Guarani)',
                'morcego':'Andirá',
                'marimbondo':'Caba (Tupi-Guarani)',
                'mel':'Ira (Tupi-Guarani)',
                'Maracanã':'paracau-aná (Tupi-Guarani)',
                'Mingau':'mi-caú (Tupi-Guarani)',
                'Mocotó':'mo-coto (Tupi-Guarani)',
                'Mutirão':'pitibõ ou popitibõ ou picorõ (Tupi-Guarani)',
                'Mutum':'plumagem (Tupi-Guarani)',
                'Monte de conchas':'Tambakï (Tupi)',
                'Moqueca':'Pokeka (Tupi)',
                'Macaco':'Sagüi (Tupi-Guarani)',
                'Mestiço':'Mamai-ruuca (Tupi-Guarani)',
                'Mãe dágua':'Yara (Tupi)',
                "manca" : 'parĩ (Kaiowá)',


                'nariz':'nhãpynha (Kawahiva)',
                'não':'maiçá (Paresí) ou Ñiá (Tupi-guarani)',
                'Nós':'íandé(tupi antigo)',
                'Nevoeiro':'ibitinga(Tupi-guarani)',
                'Nuvem':'uaaté (Tupi-guarani)',
                'ninho':'Araraquara (Tupi) ou Ayty (Tupi)',
                'nascer':'nascer do dia = Aracê (Tupi)',
                'noite':'Pituna (Tupi) ou yputuna (Kawahiva) ',
                'nômade':'goitacá (Kawahiva) ',
                'nuca' :'jirypya (Kawahiva) ',
                "nuvem" : 'paráry (Kaiowá)' ,


                'olho de boi':'onoê (Paresí)',
                'onça-hu' :'(xavante)',
                'oka':'casa de indio v.ocara, manioca ( Tupi)',
                'onça':'jini (Tupi) Auiató (Mawé)',
                'ore':'caçar animais pequenos (Tupi)',
                'OI/OLÁ':'anauê (Tupi)',
                'Olho':'Oheha (Mawé)',
                'Orelha':'Uihapê (Mawé)',
                'Ontem':'Nhaatpó (Mawé)',



                "pedra": 'ita (Tupi)',
                'pai' : 'damama (Xavante) ou tuba (Tupi antigo)' ,
                'papagaio' : 'waihârâ (Xavante) ou azuru (Guajajara)' ,
                'peixe' : 'pirá (Tupi antigo) ou arumaxi (apalaí)' ,
                'pequeno' : 'mirim (Tupi antigo)',
                "papagaio" : 'parakáu (Kaiowá)' ,
                "pacu" : 'paku (Kaiowá)' ,


                'quina':'ahonlê (Paresí)',

                'rede':'maká (Paresí)',

                "Sol" : "kûarasy (Tupi)",
                "sabiá": 's-apia ( tupi)' ,
                "saci-perere" : 'çá-aci (tupi)',
                "Sonhar": 'Aquahú (Guajajara)',
                "Sim": 'Eré (Guajajara)',
                'Sujo': 'Kiá (nheengatu)',
                "Sítio" : "Tendaua (nheengatu)",
                "Sentar" :'Duhicé (Tucana)',
                "Soprar" : 'Pukticé (Tucana)',
                'Surdo' : 'Çampanón (Kaiapo)',
                'Sumir':'Itó (Kaiapo)',
                'Saber':'Epu`tî (Makuxi)',
                'Sair': 'Anrîmaka (Makuxi)',
                'Sincero': 'Etê (Tupi)',
                'Seio': 'Camb (Tupi)',


                'terra':'uaikôen (Paresí)',


                'urubu':'olohôn (Paresí)',


                'veneno':'zamarí (Paresí)',


                "quando": 'tikat (Karitiána)',
                "quatro": 'otadnamynt (Tupi)',
                "queimar": 'pipop (Tupi)',
                "quem": "morã (Tupi) ou mobo (Karajá)",


                "noivo" : 'abaíba (Tupi) ' ,
                "gordo": 'abirú (Tupi) ' ,
                "enforcar": 'aîubika (Tupi)' ,
                "graveto": 'akãi (Tupi)' ,
                "mensageiro": 'amanajé (Tupi)' ,
                "última": 'kaiowá (Kaiowá)',
                "caçula": 'pahagwe (Kaiowá)' ,
                "sacerdote" : ' pa i (Kaiowá)',
                "xamã" :'Pa i Jirutipu (Kaiowá)',
                "sol" : 'Pa i Kwara (Kaiowá)' ,
                "descendente" : 'paĩ (Kaiowá)' ,
                "líder espiritual" : 'pa i hechakáry (Kaiowá)' ,
                "girassol" : 'paĩ poty (Kaiowá)' ,
                "inferno" : 'pa i rei (Kaiowá)' ,
                "mar" : 'para (Kaiowá)' ,










}
palavra = input("Digite Palavra em portugues: ")
if palavra in dic_indigena:
  valor = dic_indigena[palavra]
  print("A correspondencia à palavra", palavra, "é", valor)
else:
  print("Desculpe, ainda não catalogamos esta palavra.")
#Buscando valor com base na chave
#if palavra == dic_indigena.get(input("Digite a palavra em portugues: ")):
#if palavra == dic_indígena:
#  print(palavra)
#else:  # Está linha de código para informar que não temos a palavra
#  print('Desculpe, ainda não catalogamos esta palavra')
